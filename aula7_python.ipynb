# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe2208/Flowers/blob/main/aula7_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# while --> enquanto

# contador = 1
# while contador <= 5:
#     print('Número', contador)
#     contador = contador + 1  --->  # contador += 1



# contador = 10
# while contador > 0:
#     print(contador)
#     contador -= 1
#     print('Contagem')



# senha_correta = 'senha123'
# tentativas = 3

# while tentativas > 0:
#     senha = input('Digite a senha: ')
#     if senha == senha_correta:
#       print('Acesso concedido.')
#       break #sai do loop se a senha estiver corrreta
#     else:
#       tentativas -= 1   #tira uma tentativa toda vez que errar a senha
#       print(f'senha incorreta. Tentativas restantes: {tentativas}')   #f --> format, serve para conseguir escrever a variável por extenso

# if tentativas == 0:
#   print('Acesso bloqueado.')



# nome = 'Ana'

# while nome == 'Ana':
#     print(f'Olá {nome}')
#     break
# else:
#     print(f'Olá {nome}')



# **Exercício 1: Contagem regressiva simples**
# Escreva um programa que exiba uma contagem regressiva de 10 a 1, e depois imprima "Fogo!".

# texto = 'Fogo'
# contagem = 10

# while contagem > 0:
#     print(contagem)
#     contagem -= 1

# if contagem == 0:
#       print(texto)



# **Exercício 2: Soma de números pares**
# Peça ao usuário que insira um número inteiro positivo e, em seguida, calcule a soma de todos os números pares de 2 até o número inserido.

# n = int(input('Insira um número positivo: '))
# soma_pares = 0
# c = 2
# while c <= n:
#   soma_pares += c
#   c += 2

# print(f'Soma dos números pares de {n} é = {soma_pares}')



# **Exercício 3: Tabuada de multiplicação**
# Peça ao usuário para inserir um número inteiro e mostre a tabuada de multiplicação desse número de 1 a 10.

# n = int(input('Digite um número para saber a tabuada: '))
# c = 0


# while c <= 10:
#   r = n * c
#   print(f'{n}x{c} = {r}')
#   c += 1



# **Exercício 4: Números ímpares reversos**
# Exiba uma contagem regressiva de números ímpares de 99 a 1.
# c = 99
# while c >= 1:
#   print(c)
#   c-=2



# import random   #O método random() em Python não é um método, mas uma função da biblioteca random que gera números de ponto flutuante aleatórios no intervalo de 0 (inclusivo) a 1 (exclusivo).

# n = random.random()
# print(n)



# import random

# print('''Jogo de adivinhação
# Tente acertar o número da máquina''')

# tentativas = 3

# while tentativas > 0:
#     numero_do_sistema = random.randint(1, 10)
#     chute = int(input('Digite seu chute: '))

#     if chute == numero_do_sistema:
#         print(f'Sensacional, você acertou! O número da máquina é: {numero_do_sistema}')
#         break
#     else:
#         tentativas -= 1
#         print(f'Você errou! O número da máquina é: {numero_do_sistema}')

# if tentativas == 0:
#     print('Acabaram suas chances')
# Out:
# 0.8675904361139197
